# %%
#import packages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel('SDR_burned_area_1.xlsx') #Read excel file

# %%
df.head()
# Out:
#    zone  count  count_2    AREA  MONTH  YEAR  id1        LULC IBGE  LULC_1  \
# 0  1009     15       72   1.239     10  2019  405  Eucalyptus    E     109
# 1  1009     45       44   3.633     10  2011  233  Eucalyptus    E     109
# 2  1009     23      186   1.899     10  2011  230  Eucalyptus    E     109
# 3  1009    110      112   7.026     10  2014  342  Eucalyptus    E     109
# 4  1003    136     3967  11.236     10  2014  337         HAG    r     203
#
#    ...  ES_EXPORT/  ES_AVOID/H  d_riversme  d_rivers_1      RIVERS  \
# 0  ...    3.768632    3.644567  261.544904  256.478546  190.804214
# 1  ...    0.974985    2.665455  177.993156  174.104858  112.500000
# 2  ...    1.655464    4.111118  190.326593  194.854073   70.710678
# 3  ...    0.161882    0.226702  235.470778  227.244118  100.000000
# 4  ...    4.824746   13.093077  294.400254  292.617493   50.000000
#
#    d_riversma   D_roadsmea   D_roadsmed        ROADS   D_roadsmax
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   zone               542 non-null    int64
#  1   count              542 non-null    int64
#  2   count_2            542 non-null    int64
#  3   AREA               542 non-null    float64
#  4   MONTH              542 non-null    int64
#  5   YEAR               542 non-null    int64
#  6   id1                542 non-null    int64
#  7   LULC               542 non-null    object
#  8   IBGE               542 non-null    object
#  9   LULC_1             542 non-null    int64
#  10  LUCODE             542 non-null    float64
#  11  IIS                542 non-null    float64
#  12  _median            542 non-null    float64
#  13  _stdev             542 non-null    float64
#  14  ELEVATION          542 non-null    float64
#  15  _ALTITUD_1         542 non-null    float64
# ...

# %%
#df = df[df['LULC_1'] >109]

# %%
g=sns.relplot(
    data=df, x="YEAR", y="EXPORT_BALANCE",col = "LULC", kind="line", col_wrap = 3, height=4, aspect=1.5)
(g.map(plt.axhline, y=0, color="1", dashes=(2,1), zorder=0)
  .set_axis_labels("Year", "Sediment export balance (ton.yr-1)")
  .set_titles(" {col_name}")
  .tight_layout(w_pad=0))
fig = g
plt.savefig ('Export_balance_year.tif', format = "tif")

# %%
df['y'].value_counts()
# Out:
# YES    532
# NO      10
# Name: y, dtype: int64

# %%
df['target'] = df['y'].apply(lambda x : 1 if x == 'YES' else 0)  # Convert to numeric
df = df.drop('y',axis=1)

# %% [markdown]
# WOE and IV

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(df,df.target)
# Out:
# C:\Users\cheil\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\cheil\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\cheil\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\cheil\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
final_iv
# Out:
#       VAR_NAME MIN_VALUE MAX_VALUE  COUNT  EVENT  EVENT_RATE  NONEVENT  \
# 0         zone       103       903    235    235    1.000000         0
# 1         zone       915      1003    219    216    0.986301         3
# 2         zone      1009      1215     88     81    0.920455         7
# 3        count        13        25    194    188    0.969072         6
# 4        count        26        59    168    166    0.988095         2
# ..         ...       ...       ...    ...    ...         ...       ...
# 148    USLE_HA   18.3972   455.107    271    271    1.000000         0
# 149  EXPORT_HA  -1.03508   1.04885    271    261    0.963100        10
# 150  EXPORT_HA   1.05213   38.7048    271    271    1.000000         0
# 151   AVOID_HA  -10.9393     2.755    271    261    0.963100        10
# 152   AVOID_HA   2.82008   163.759    271    271    1.000000         0
#
#      NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE        IV
# ...

# %%
final_iv.to_csv('WOE_Soil_loss_RESULTADO.csv')

# %%
IV.sort_values('IV')
# Out:
#              VAR_NAME        IV
# 36             _stdev  0.000000
# 19              SLOPE  0.000000
# 33         _RADIAÃ‡_2  0.000000
# 29         _ERODIBI_2  0.000000
# 4         EXPORT_POST  0.000000
# 24         _ALTITUDEs  0.000000
# 31         _EROSIVI_2  0.000486
# 12           PRIORITY  0.019117
# 5          EXPORT_PRE  0.019554
# 26         _DECLIVE_1  0.019554
# 35         _priormedi  0.019680
# 34            _median  0.038629
# 13          RADIATION  0.042075
# 23           USLE_PRE  0.042075
# 27         _DECLIVEst  0.042075
# 32         _RADIAÃ‡_1  0.042075
# 22          USLE_POST  0.042075
# 39            count_2  0.045216
# 7                 IIS  0.050886
# 6                IBGE  0.054436
# 10               LULC  0.100797
# 42             lulc_1  0.100797
# 25         _ALTITUD_1  0.175709
# 15     RETENTION_POST  0.175709
# 1           ELEVATION  0.175709
# 16      RETENTION_PRE  0.175709
# 28         _ERODIBI_1  0.177256
# 8            K_FACTOR  0.188773
# ...

# %%
IV.to_csv('test.csv')

# %% [markdown]
# **Apply WOE values to your dataframe columns**

# %% [markdown]
# The below code snippet can be used to apply the WOE values to your dataframe columns.

# %%
transform_vars_list = df.columns.difference(['target'])
transform_prefix = 'new_' # leave this value blank if you need replace the original column values

# %%
transform_vars_list
# Out:
# Index(['Burned area', 'Conservation unid categorie', 'Conservation unit',
#        'Deforested and burning area', 'Deforested area',
#        'Distance to antropogenic Land Use', 'Distance to watercourses',
#        'Estage', 'IDI 0 ', 'IDI 1', 'IDI 2', 'IDI 3', 'Land use',
#        'Phytosfisionomie', 'Year'],
#       dtype='object')

# %%
for var in transform_vars_list:
    small_df = final_iv[final_iv['VAR_NAME'] == var]
    transform_dict = dict(zip(small_df.MAX_VALUE,small_df.WOE))
    replace_cmd = ''
    replace_cmd1 = ''
    for i in sorted(transform_dict.items()):
        replace_cmd = replace_cmd + str(i[1]) + str(' if x <= ') + str(i[0]) + ' else '
        replace_cmd1 = replace_cmd1 + str(i[1]) + str(' if x == "') + str(i[0]) + '" else '
    replace_cmd = replace_cmd + '0'
    replace_cmd1 = replace_cmd1 + '0'
    if replace_cmd != '0':
        try:
            df[transform_prefix + var] = df[var].apply(lambda x: eval(replace_cmd))
        except:
            df[transform_prefix + var] = df[var].apply(lambda x: eval(replace_cmd1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-e8bf8a66b6b0> in <module>
#       4     replace_cmd = ''
#       5     replace_cmd1 = ''
# ----> 6     for i in sorted(transform_dict.items()):
#       7         replace_cmd = replace_cmd + str(i[1]) + str(' if x <= ') + str(i[0]) + ' else '
#       8         replace_cmd1 = replace_cmd1 + str(i[1]) + str(' if x == "') + str(i[0]) + '" else '
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
df['Burned area'].value_counts()
# Out:
# 17.25561    12
# 22.43650     8
# 7.48629      8
# 9.89533      7
# 2.46780      7
#             ..
# 2.47369      1
# 2.47228      1
# 2.46549      1
# 4.87331      1
# 4.92804      1
# Name: Burned area, Length: 916, dtype: int64

# %%
df['Burned area'].value_counts()
# Out:
# 17.25561    12
# 22.43650     8
# 7.48629      8
# 9.89533      7
# 2.46780      7
#             ..
# 2.47369      1
# 2.47228      1
# 2.46549      1
# 4.87331      1
# 4.92804      1
# Name: Burned area, Length: 916, dtype: int64

# %%
small_df = final_iv[final_iv['VAR_NAME'] == 'Burned area']

# %%
small_df
# Out:
#       VAR_NAME MIN_VALUE MAX_VALUE  COUNT  EVENT  EVENT_RATE  NONEVENT  \
# 4  Burned area   0.16221   2.47107    429    149    0.347319       280
# 5  Burned area    2.4711   4.95169    428    128    0.299065       300
# 6  Burned area   4.95348   121.026    429    112    0.261072       317
#
#    NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE        IV
# 4        0.652681    0.383033        0.312152  0.204633  0.028012
# 5        0.700935    0.329049        0.334448 -0.016276  0.028012
# 6        0.738928    0.287918        0.353400 -0.204926  0.028012

# %%
small_df.to_csv('UC_WOE_anthr.csv')

# %%
pip install StatSignificance
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement StatSignificance (from versions: none)
# ERROR: No matching distribution found for StatSignificance

# %%
objects1 = ('114','170','260','2955')
x1 = np.arange(len(objects1))
y1 = [-0.931146978,0.071377602,0.15631558,0.471254369]
plt.bar(x1, y1, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('WOE',  fontsize = 14)
plt.xlabel ('Distance to anthropogenic land uses',  fontsize = 14)
fig = plt.gcf()
plt.savefig ('Distance_anthropogenic_WOE_UC.tif', format = "tif")
plt.show()

# %%
objects2 = ('2.5','5','120')
x2 = np.arange(len(objects2))
y2 = [0.204633221,0.016275692,-0.204926384]
plt.bar(x2, y2, align='center', alpha=0.5)
plt.xticks(x2, objects2)
#plt.ylabel('WOE')
plt.xlabel ('Total burned area (ha)', fontsize = 14)

plt.show()

# %%
objects3 = ('5','6')
x3 = np.arange(len(objects3))
y3 = [-0.297229982,0.324650895]
plt.bar(x3, y3, align='center', alpha=0.5)
plt.xticks(x3, objects3)
#plt.ylabel('WOE')
plt.xlabel ('IDS 3 year later',  fontsize = 14)

plt.show()
