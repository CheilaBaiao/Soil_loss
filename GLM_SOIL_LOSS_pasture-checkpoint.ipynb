# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
dir(stats)
import csv
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib import pyplot as plt

plt.rc("figure", figsize=(16,8))
plt.rc("font", size=14)
#from matplotlib import rcParams
#rcParams['text.usetex'] = True
#rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'

from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_excel ('pasture_soil_loss.xlsx') #Read excel file

# %%
#df = df[['AREA','MONTH', 'YEAR','LULC','IIS','ELEVATION','SLOPE','RADIATION','K_FACTOR','R_FACTOR','PRIORITY','SEVERITY','EXPORT_BALANCE', ]]
#df = df[['AREA','IBGE','ELEVATION','SLOPE','RADIATION','EXPORT_BALANCE']]

# %%
df.head()
# Out:
#    zone  count  count_2      AREA MONTH            YEAR  id1     LULC IBGE  \
# 0   915    499     1050  0.224156   SEP  Sele̤̣o_2010  167  Pasture    P
# 1   915    281    85912  0.145911   SEP  Sele̤̣o_2010  193  Pasture    P
# 2   915    234      434  0.131532   SEP  Sele̤̣o_2010  180  Pasture    P
# 3   915    188      204  0.102240   SEP  Sele̤̣o_2003   89  Pasture    P
# 4  1015     86      105  0.043649   OCT  Sele̤̣o_2012  265  Pasture    P
#
#    LULC_  ...  RETENTION_POST  USLE_BALANCE  EXPORT_BALANCE  \
# 0    115  ...        0.337303      1.000000        1.000000
# 1    115  ...        0.276434      0.647364        0.822359
# 2    115  ...        0.153022      0.555172        0.474371
# 3    115  ...        0.086856      0.820796        0.405699
# 4    115  ...        0.084498      0.627363        0.378042
#
#    RETENTION_BALANCE   USLE_HA  EXPORT_HA  AVOID_HA    y    Rivers     Roads
# 0           0.354665  0.310230   0.341267  0.152605  YES  0.000000  0.000000
# 1           0.313554  0.302884   0.416861  0.182200  YES  0.000000  0.043140
# 2           0.179731  0.287707   0.273714  0.136288  YES  0.000000  0.082764
# 3           0.143468  0.515552   0.293812  0.135916  YES  0.000000  0.337030
# 4           0.093625  0.823430   0.559453  0.160660  YES  0.582546  0.458125
#
# [5 rows x 47 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      zone  count  count_2      AREA MONTH            YEAR  id1     LULC IBGE  \
# 0     915    499     1050  0.224156   SEP  Sele̤̣o_2010  167  Pasture    P
# 1     915    281    85912  0.145911   SEP  Sele̤̣o_2010  193  Pasture    P
# 2     915    234      434  0.131532   SEP  Sele̤̣o_2010  180  Pasture    P
# 3     915    188      204  0.102240   SEP  Sele̤̣o_2003   89  Pasture    P
# 4    1015     86      105  0.043649   OCT  Sele̤̣o_2012  265  Pasture    P
# ..    ...    ...      ...       ...   ...             ...  ...      ...  ...
# 289  1015     37    86496  0.014357   OCT  Sele̤̣o_2011  226  Pasture    P
# 290  1015     20    86496  0.004190   OCT  Sele̤̣o_2011  238  Pasture    P
# 291  1015     19    12971  0.003596   OCT  Sele̤̣o_2011  222  Pasture    P
# 292  1015     82    86496  0.040067   OCT  Sele̤̣o_2011  227  Pasture    P
# 293  1015     22       50  0.005384   OCT  Sele̤̣o_2011  247  Pasture    P
#
#      LULC_  ...  RETENTION_POST  USLE_BALANCE  EXPORT_BALANCE  \
# 0      115  ...        0.337303  1.000000e+00    1.000000e+00
# 1      115  ...        0.276434  6.473637e-01    8.223586e-01
# 2      115  ...        0.153022  5.551722e-01    4.743712e-01
# 3      115  ...        0.086856  8.207965e-01    4.056991e-01
# 4      115  ...        0.084498  6.273631e-01    3.780418e-01
# ..     ...  ...             ...           ...             ...
# 289    115  ...        0.002518  4.404880e-03    4.048118e-03
# 290    115  ...        0.004466  3.949874e-03    3.559409e-03
# 291    115  ...        0.006960  4.313636e-03    3.071917e-03
# 292    115  ...        0.009788  2.110517e-03    2.242008e-03
# 293    115  ...        0.021156  1.000000e-07    1.000000e-07
#
#      RETENTION_BALANCE       USLE_HA     EXPORT_HA  AVOID_HA    y    Rivers  \
# 0             0.354665  3.102295e-01  3.412668e-01  0.152605  YES  0.000000
# 1             0.313554  3.028840e-01  4.168610e-01  0.182200  YES  0.000000
# 2             0.179731  2.877070e-01  2.737144e-01  0.136288  YES  0.000000
# 3             0.143468  5.155522e-01  2.938123e-01  0.135916  YES  0.000000
# 4             0.093625  8.234295e-01  5.594526e-01  0.160660  YES  0.582546
# ..                 ...           ...           ...       ...  ...       ...
# 289           0.010353  2.457840e-02  2.400607e-02  0.062218   NO  0.504627
# 290           0.010246  1.889828e-02  1.926806e-02  0.061338   NO  0.195507
# 291           0.010540  2.051187e-02  1.576237e-02  0.062839   NO  0.683709
# 292           0.009930  2.343246e-02  2.232939e-02  0.061897   NO  0.295455
# 293           0.010772  1.000000e-07  1.000000e-08  0.063877   NO  0.000000
#
#         Roads
# 0    0.000000
# 1    0.043140
# 2    0.082764
# 3    0.337030
# 4    0.458125
# ..        ...
# 289  0.105250
# 290  0.000000
# 291  0.010786
# 292  0.086287
# 293  0.161777
#
# [294 rows x 47 columns]>

# %%
formula = "EXPORT_BALANCE~AREA+IIS+ELEVATION+SLOPE+RADIATION+K_FACTOR+R_FACTOR+PRIORITY+SEVERITY+Rivers+Roads"#+ELEVATION*SLOPE*RADIATION+K_FACTOR*R_FACTOR+K_FACTOR*R_FACTOR*SEVERITY"

gamma = smf.glm(formula=formula, data=df, family=sm.families.Gamma(link=sm.families.links.log())).fit()
print(gamma.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         EXPORT_BALANCE   No. Observations:                  294
# Model:                            GLM   Df Residuals:                      282
# Model Family:                   Gamma   Df Model:                           11
# Link Function:                    log   Scale:                         0.32131
# Method:                          IRLS   Log-Likelihood:                 768.55
# Date:                Tue, 25 Jul 2023   Deviance:                       109.48
# Time:                        20:35:48   Pearson chi2:                     90.6
# No. Iterations:                    23
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.9404      0.511    -11.619      0.000      -6.942      -4.938
# AREA          19.7880      1.143     17.310      0.000      17.547      22.029
# IIS            0.0079      0.117      0.068      0.946      -0.220       0.236
# ELEVATION     -0.2583      0.396     -0.653      0.514      -1.034       0.517
# SLOPE          2.4155      0.176     13.739      0.000       2.071       2.760
# RADIATION      0.0091      0.224      0.041      0.968      -0.430       0.448
# K_FACTOR       1.5446      0.280      5.518      0.000       0.996       2.093
# R_FACTOR       0.2100      0.434      0.484      0.629      -0.641       1.061
# PRIORITY      -0.0810      0.161     -0.503      0.615      -0.396       0.234
# SEVERITY       1.2253      0.271      4.519      0.000       0.694       1.757
# Rivers        -1.3593      0.177     -7.669      0.000      -1.707      -1.012
# Roads          0.1392      0.284      0.490      0.624      -0.418       0.697
# ==============================================================================

# %%
formula = "USLE_BALANCE~AREA+IIS+ELEVATION+SLOPE+RADIATION+K_FACTOR+R_FACTOR+PRIORITY+SEVERITY+Rivers+Roads"#+ELEVATION*SLOPE*RADIATION+K_FACTOR*R_FACTOR+K_FACTOR*R_FACTOR*SEVERITY"

gamma = smf.glm(formula=formula, data=df, family=sm.families.Gamma(link=sm.families.links.log())).fit()
print(gamma.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           USLE_BALANCE   No. Observations:                  542
# Model:                            GLM   Df Residuals:                      530
# Model Family:                   Gamma   Df Model:                           11
# Link Function:                    log   Scale:                         0.92147
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Tue, 25 Jul 2023   Deviance:                       501.28
# Time:                        17:57:37   Pearson chi2:                     488.
# No. Iterations:                    66
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -9.5884      0.557    -17.207      0.000     -10.681      -8.496
# AREA          11.9286      0.755     15.789      0.000      10.448      13.409
# IIS            0.0508      0.153      0.333      0.739      -0.248       0.350
# ELEVATION      1.8042      0.478      3.776      0.000       0.868       2.741
# SLOPE          2.7773      0.243     11.443      0.000       2.302       3.253
# RADIATION      2.3471      0.234     10.030      0.000       1.888       2.806
# K_FACTOR      -0.0082      0.396     -0.021      0.983      -0.784       0.767
# R_FACTOR       1.7018      0.477      3.570      0.000       0.768       2.636
# PRIORITY       0.2670      0.240      1.114      0.265      -0.203       0.737
# SEVERITY       2.1417      0.276      7.749      0.000       1.600       2.683
# Rivers        -0.2185      0.231     -0.947      0.344      -0.671       0.234
# Roads         -0.0204      0.270     -0.076      0.940      -0.550       0.509
# ==============================================================================
# C:\Users\cheil\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)

# %%
formula = "RETENTION_BALANCE~AREA+IIS+ELEVATION+SLOPE+RADIATION+K_FACTOR+R_FACTOR+PRIORITY+SEVERITY+Rivers+Roads"#+ELEVATION*SLOPE*RADIATION+K_FACTOR*R_FACTOR+K_FACTOR*R_FACTOR*SEVERITY"

gamma = smf.glm(formula=formula, data=df, family=sm.families.Gamma(link=sm.families.links.log())).fit()
print(gamma.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:      RETENTION_BALANCE   No. Observations:                  542
# Model:                            GLM   Df Residuals:                      530
# Model Family:                   Gamma   Df Model:                           11
# Link Function:                    log   Scale:                         0.72466
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Tue, 25 Jul 2023   Deviance:                       302.91
# Time:                        19:09:04   Pearson chi2:                     384.
# No. Iterations:                    62
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7564      0.494    -11.649      0.000      -6.725      -4.788
# AREA          13.2623      0.670     19.795      0.000      11.949      14.575
# IIS           -0.1343      0.135     -0.992      0.321      -0.400       0.131
# ELEVATION     -0.1030      0.424     -0.243      0.808      -0.933       0.727
# SLOPE          0.7709      0.215      3.582      0.000       0.349       1.193
# RADIATION     -0.0452      0.208     -0.218      0.827      -0.452       0.361
# K_FACTOR       0.9007      0.351      2.568      0.010       0.213       1.588
# R_FACTOR       1.0757      0.423      2.545      0.011       0.247       1.904
# PRIORITY       0.3089      0.213      1.453      0.146      -0.108       0.726
# SEVERITY       0.7711      0.245      3.146      0.002       0.291       1.252
# Rivers        -1.1967      0.205     -5.849      0.000      -1.598      -0.796
# Roads          0.1184      0.240      0.494      0.621      -0.351       0.588
# ==============================================================================
# C:\Users\cheil\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)
