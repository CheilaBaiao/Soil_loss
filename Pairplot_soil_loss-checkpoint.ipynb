# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
dir(stats)
import csv

#from matplotlib import rcParams
#rcParams['text.usetex'] = True
#rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'

from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

# %%
#Função de leitura dos dados------------------------------------
def pd_data(path):
    with open(path, newline='') as f:
        reader = csv.reader(f,delimiter=',')
        next(reader, None)  # ignora o cabeçalho
        for row in reader:
            try:
                data = np.vstack( (data , np.asarray(row).astype(np.float) ) )
            except:
                data = np.asarray(row).astype(np.float)
    f.close()
    return data

# %%
df = pd.read_excel ('SDR_burned_area_pairplot.xlsx') #Read excel file

# %%
#df = df[['AREA','IBGE','IIS','ELEVATION','SLOPE','RADIATION','K_FACTOR','R_FACTOR','PRIORITY','SEVERITY','EXPORT_BALANCE']]
df = df[['AREA','IBGE','ELEVATION','SLOPE','RADIATION','EXPORT_BALANCE']]

# %%
df.head()
# Out:
#      AREA IBGE    ELEVATION      SLOPE    RADIATION  EXPORT_BALANCE
# 0  32.050    P  1050.517241  22.533127  4710.230805      401.484800
# 1  21.237    P   845.180000  23.287876  3947.185950      329.830360
# 2  19.250    P   969.433090  22.272459  4121.147144      189.464247
# 3  15.202    P   924.897751  21.933177  4547.242461      161.764282
# 4   7.105    P  1249.751606  35.394902  4742.645264      150.608280

# %%
df.info
# Out:
# <bound method DataFrame.info of        AREA IBGE    ELEVATION      SLOPE    RADIATION  EXPORT_BALANCE
# 0    32.050    P  1050.517241  22.533127  4710.230805      401.484800
# 1    21.237    P   845.180000  23.287876  3947.185950      329.830360
# 2    19.250    P   969.433090  22.272459  4121.147144      189.464247
# 3    15.202    P   924.897751  21.933177  4547.242461      161.764282
# 4     7.105    P  1249.751606  35.394902  4742.645264      150.608280
# ..      ...  ...          ...        ...          ...             ...
# 527   1.073    D  1143.014493  15.094509  4369.711946        0.002684
# 528   1.487    D  1122.247191  15.763863  3142.870312        0.002496
# 529   1.321    P   917.583333   5.752402  4617.943149        0.000000
# 530   3.140    P   648.813131   9.229980  3892.300853        0.000000
# 531   3.224    P   730.538095  19.551892  6082.663697        0.000000
#
# [532 rows x 6 columns]>

# %%
sns.pairplot(df, diag_kind="hist")

# %%
df = pd.read_excel ('SDR_burned_area_1.xlsx') #Read excel file

# %%
#df = df[['AREA','IBGE','IIS','ELEVATION','SLOPE','RADIATION','K_FACTOR','R_FACTOR','PRIORITY','SEVERITY','EXPORT_BALANCE']]
#df = df[['AREA','IBGE','ELEVATION','SLOPE','RADIATION','EXPORT_BALANCE']]
df = df[['IBGE','K_FACTOR','R_FACTOR','PRIORITY','SEVERITY','EXPORT_BALANCE']]

# %%
sns.pairplot(df, hue="IBGE", diag_kind="hist")

# %%
df = pd.read_excel ('SDR_burned_area_1.xlsx') #Read excel file

# %%
df = df[['IBGE','USLE_BALANCE','EXPORT_BALANCE','RETENTION_BALANCE']]

# %%
sns.pairplot(df, hue="IBGE", diag_kind="hist")
